# %%
# Library installation
# !pip install openai==0.28

# %%
import os
import openai
import pandas as pd

# Load API key securely
openai.api_key = os.getenv(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)

# Load and parse the mutual fund data
try:
    df = pd.read_csv("MFrecommendation.csv")
    mutual_fund_data = df.to_dict(orient='records')
except FileNotFoundError:
    print("Error: The CSV file was not found.")
    sys.exit(1)

# Initialize context
context = [{'role': 'system', 'content': "You are a Mutual Fund Recommender..."}]

# Fetch messages
def fetch_messages(messages, model="gpt-3.5-turbo", temperature=0):
    try:
        response = openai.ChatCompletion.create(
            model=model,
            messages=messages,
            temperature=temperature,
        )
        return response.choices[0].message["content"]
    except openai.error.OpenAIError as e:
        print(f"OpenAI API error: {e}")
        return "Sorry, something went wrong. Please try again later."

# Refresh context
def refresh_conversation(chat, max_context_length=10):
    context.append({'role': 'user', 'content': chat})
    if len(context) > max_context_length:
        context.pop(1)
    response = fetch_messages(context, temperature=0.7)
    context.append({'role': 'assistant', 'content': response})
    print(response)

# Main loop
def main():
    print("Welcome to the Mutual Fund Recommender!")
    while True:
        message = input("Enter your query (or 'exit' to quit): ")
        if message.lower() == 'exit':
            break
        refresh_conversation(message)

if __name__ == '__main__':
    main()
# Out:
#   File "<ipython-input-6-f333c1ba0344>", line 7
#     OPENAI_KEY = userdata.get (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)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
#                                                                                                       ^
# SyntaxError: invalid decimal literal
